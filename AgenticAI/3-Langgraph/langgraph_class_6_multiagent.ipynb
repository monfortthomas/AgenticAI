# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
llm.invoke("hi hello how are you?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm.invoke("hi hello how are you?")
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_openai\chat_models\base.py:973, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     971     generation_info = {"headers": dict(raw_response.headers)}
#     972 else:
# --> 973     response = self.client.create(**payload)
#     974 return self._create_chat_result(response, generation_info)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)
#     922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)
#    1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from langgraph.types import Command

# %%
from langgraph.prebuilt import create_react_agent

# %%
# class AgentState(TypedDict):
#     messages: Annotated[Sequence[BaseMessage], add_messages]
#     Name:str
#     age:int
#     DOB:int

# %%
def add_number(state):
    result=state["num1"]+state["num2"]
    print(f"addition is {result}")
    return Command(goto="multiply",update={"sum":result})

# %%
state={"num1":10,"num2":20}

# %%
add_number(state)
# Out:
# addition is 30
# Command(update={'sum': 30}, goto='multiply')

# %% [markdown]
# ### Creating one dummy multiagent
#
# it is for network/collab multiagent

# %%
from langchain_core.tools import tool

# %%
@tool
def transfer_to_multiplication_expert():
    """Ask multiplication agent for help"""
    return

# %%
@tool
def transfer_to_addition_expert():
    """Ask addition agent for help"""
    return

# %%
llm_with_tool=llm.bind_tools([transfer_to_addition_expert, transfer_to_multiplication_expert])

# %%
response=llm_with_tool.invoke("hi")

# %%
response.content
# Out:
# 'Hello! How can I assist you today?'

# %%
response.tool_calls
# Out:
# []

# %%
response=llm_with_tool.invoke("what is 2+2?")

# %%
response.content
# Out:
# ''

# %%
response.tool_calls
# Out:
# [{'name': 'transfer_to_addition_expert',
#   'args': {},
#   'id': 'call_zinN4RRH7AaQDDjdPqOhnKFx',
#   'type': 'tool_call'}]

# %%
system_prompt = (
        "You are an addition expert, you can ask the multiplication expert for help with multiplication."
        "Always do your portion of calculation before the handoff."
    )

# %%
messages = [{"role": "system", "content": system_prompt}] + ["can you tell me the addition of 2 and 2?"]

# %%
messages
# Out:
# [{'role': 'system',
#   'content': 'You are an addition expert, you can ask the multiplication expert for help with multiplication.Always do your portion of calculation before the handoff.'},
#  'can you tell me the addition of 2 and 2?']

# %% [markdown]
# [{'role': 'system',
#   'content': 'You are an addition expert, you can ask the multiplication expert for help with multiplication.Always do your portion of calculation before the handoff.'},
#  'can you tell me the addition of 2 and 2?']

# %%
from typing_extensions import Literal
from langgraph.graph import MessagesState,StateGraph, START,END

# %%
def additional_expert(state:MessagesState)-> Command[Literal["multiplication_expert", "__end__"]]:
    
    system_prompt = (
        "You are an addition expert, you can ask the multiplication expert for help with multiplication."
        "Always do your portion of calculation before the handoff."
    )
    
    messages = [{"role": "system", "content": system_prompt}] + state["messages"]
    
    
    ai_msg = llm.bind_tools([transfer_to_multiplication_expert]).invoke(messages)
    
    
    if len(ai_msg.tool_calls) > 0:
        tool_call_id = ai_msg.tool_calls[-1]["id"]
        tool_msg = {
            "role": "tool",
            "content": "Successfully transferred",
            "tool_call_id": tool_call_id,
        }
        
        return Command(
            goto="multiplication_expert", update={"messages": [ai_msg, tool_msg]}
        )
    return {"messages": [ai_msg]}

# %%
##Agent2
def multiplication_expert(state:MessagesState)-> Command[Literal["additional_expert", "__end__"]]:
    
    system_prompt = (
        "You are a multiplication expert, you can ask an addition expert for help with addition. "
        "Always do your portion of calculation before the handoff."
    )
    
    messages = [{"role": "system", "content": system_prompt}] + state["messages"]
    
    ai_msg = llm.bind_tools([transfer_to_addition_expert]).invoke(messages)
    
    if len(ai_msg.tool_calls) > 0:
        tool_call_id = ai_msg.tool_calls[-1]["id"]
        tool_msg = {
            "role": "tool",
            "content": "Successfully transferred",
            "tool_call_id": tool_call_id,
        }
        return Command(goto="additional_expert", update={"messages": [ai_msg, tool_msg]})
    return {"messages": [ai_msg]}

# %%
graph=StateGraph(MessagesState)

# %%
graph.add_node("additional_expert",additional_expert)
graph.add_node("multiplication_expert",multiplication_expert)

# %%
graph.add_edge(START, "additional_expert")

# %%
app=graph.compile()

# %%
app.invoke({"messages":[("user","what's (3 + 5) * 12. Provide me the output")]})
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 app.invoke({"messages":[("user","what's (3 + 5) * 12. Provide me the output")]})
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\pregel\__init__.py:2719, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2716 chunks: list[Union[dict[str, Any], Any]] = []
#    2717 interrupts: list[Interrupt] = []
# -> 2719 for chunk in self.stream(
#    2720     input,
#    2721     config,
#    2722     stream_mode=stream_mode,
#    2723     output_keys=output_keys,
#    2724     interrupt_before=interrupt_before,
#    2725     interrupt_after=interrupt_after,
#    2726     checkpoint_during=checkpoint_during,
#    2727     debug=debug,
#    2728     **kwargs,
#    2729 ):
#    2730     if stream_mode == "values":
#    2731         if (
#    2732             isinstance(chunk, dict)
#    2733             and (ints := chunk.get(INTERRUPT)) is not None
#    2734         ):
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\pregel\__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\pregel\runner.py:161, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     159 t = tasks[0]
#     160 try:
# --> 161     run_with_retry(
#     162         t,
#     163         retry_policy,
#     164         configurable={
#     165             CONFIG_KEY_CALL: partial(
#     166                 _call,
#     167                 weakref.ref(t),
#     168                 retry=retry_policy,
#     169                 futures=weakref.ref(futures),
#     170                 schedule_task=schedule_task,
#     171                 submit=self.submit,
#     172             ),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[33], line 11, in multiplication_expert(state)
#       4 system_prompt = (
#       5     "You are a multiplication expert, you can ask an addition expert for help with addition. "
#       6     "Always do your portion of calculation before the handoff."
#       7 )
#       9 messages = [{"role": "system", "content": system_prompt}] + state["messages"]
# ---> 11 ai_msg = llm.bind_tools([transfer_to_addition_expert]).invoke(messages)
#      13 if len(ai_msg.tool_calls) > 0:
#      14     tool_call_id = ai_msg.tool_calls[-1]["id"]
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\runnables\base.py:5430, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5423 @override
#    5424 def invoke(
#    5425     self,
#    (...)
#    5428     **kwargs: Optional[Any],
#    5429 ) -> Output:
# -> 5430     return self.bound.invoke(
#    5431         input,
#    5432         self._merge_configs(config),
#    5433         **{**self.kwargs, **kwargs},
#    5434     )
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_core\language_models\chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\langchain_openai\chat_models\base.py:973, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     971     generation_info = {"headers": dict(raw_response.headers)}
#     972 else:
# --> 973     response = self.client.create(**payload)
#     974 return self._create_chat_result(response, generation_info)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)
#     922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)
#    1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Monfort\AgenticAI\env\lib\site-packages\openai\_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_62r9i7YqJTqpBJTtwWQKLGhX", 'type': 'invalid_request_error', 'param': 'messages', 'code': None}}

# %% [markdown]
# ## With realtime tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun

# %%
# search_tool=DuckDuckGoSearchRun()

import os
from langchain_community.tools.tavily_search import TavilySearchResults
TAVILY_API_KEY=os.getenv("TAVILY_API_KEY")
search_tool=TavilySearchResults(tavily_api_key=TAVILY_API_KEY)

# %%
search_tool.invoke("who is a current pm of uk?")
# Out:
# [{'title': 'Prime Minister - GOV.UK',
#   'url': 'https://www.gov.uk/government/ministers/prime-minister',
#   'content': '## Contents\n\n## Responsibilities\n\nThe Prime Minister is the leader of His Majesty’s Government and is ultimately responsible for the policy and decisions of the government.\n\nAs leader of the UK government the Prime Minister also:\n\n## Current role holder\n\n### The Rt Hon Sir Keir Starmer KCB KC MP\n\nSir Keir Starmer\xa0became Prime Minister on 5 July 2024.\n\n## Education [...] Keir qualified as a barrister in 1987 working in private practice before working as a legal advisor to the Northern Ireland Policing Board.\n\nHe was appointed Queen’s Counsel (QC) in 2002.\n\nIn 2008, Keir was appointed Director of Public Prosecutions, leading the Crown Prosecution Service until 2013.\n\nHe received a knighthood in 2014 for services to criminal justice.\n\n## Personal Life\n\nKeir is married and has two children.\n\n[More about this person](/government/people/keir-starmer) [...] Keir attended Reigate Grammar School, before studying Law\xa0at the University of Leeds. He went on to do postgraduate studies at the University of Oxford, receiving a Bachelor of Civil Law (BCL) degree.\n\n## Political Career\n\nKeir was elected a Member of Parliament for Holborn and St Pancras in May 2015. He was elected leader of the Labour Party in April 2020.\n\n## Career before politics',
#   'score': 0.81979275},
#  {'title': 'UK Prime Minister - Facebook',
#   'url': 'https://www.facebook.com/10downingstreet/',
#   'content': 'UK Prime Minister. 1102975 likes · 22817 talking about this. Official page for the office of Prime Minister Keir Starmer, based at 10 Downing Street.',
#   'score': 0.750937},
#  {'title': "Keir Starmer becomes UK's new prime minister - YouTube",
#   'url': 'https://www.youtube.com/watch?v=LDA825-Uymg',
#   'content': "# U.K. elects new prime minister | Keir Starmer becomes UK's new prime minister [...] 13WMAZ\n119 likes\n35581 views\n5 Jul 2024\n(ASSOCIATED PRESS) For someone often derided as dull, Keir Starmer has delivered a sensational election result.\r\n\r\nStarmer led Britain’s Labour Party to a landslide election victory, and on Friday became the country’s 58th prime minister — the first leader from the center-left party to win a U.K. national election since Tony Blair, who won three in a row starting in 1997. [...] It’s the latest reinvention for a man who went from human rights attorney to hard-nosed prosecutor and from young radical to middle-aged pragmatist.\r\n\r\nLike Blair, who refashioned the party as “New Labour” in the 1990s, 61-year-old Starmer led Labour to a landslide victory over Rishi Sunak’s Conservative Party in Thursday’s election after dragging the party towards the political middle ground.",
#   'score': 0.7192461},
#  {'title': 'Rishi Sunak | Biography, Wife, Politics, & Net Worth - Britannica',
#   'url': 'https://www.britannica.com/biography/Rishi-Sunak',
#   'content': '**Rishi Sunak** (born May 12, 1980, Southampton, England) is a British politician and financier who became the leader of the [Conservative Party](https://www.britannica.com/topic/Conservative-Party-political-party-United-Kingdom) and prime minster of the [United Kingdom](https://www.britannica.com/place/United-Kingdom) in October 2022. He resigned as [prime minister](https://www.britannica.com/topic/prime-minister) in July 2024 and was replaced by Labour Party leader [Keir [...] previously endeavored to characterize his government as a break with the past. The return of Cameron to front bench politics did little to buoy Conservative fortunes, and polls of voting intent consistently showed the [Labour Party](https://www.britannica.com/topic/Labour-Party-political-party) holding a sizable lead over the Conservatives. Thus, it came as a surprise in May 2024 when Sunak announced that a general election would be held in July of that year, more than six months ahead of the [...] In November 2023 Sunak sacked controversial home secretary Suella Braverman as part of a broader cabinet reshuffle that saw the stunning return to government of former prime minister [David Cameron](https://www.britannica.com/biography/David-Cameron) as foreign secretary. Cameron, who was elevated to the [House of Lords](https://www.britannica.com/topic/House-of-Lords) and created Lord Cameron of Chipping Norton in order to take his seat in the cabinet, seemed an unusual choice, as Sunak had',
#   'score': 0.70847535},
#  {'title': 'How government works - GOV.UK',
#   'url': 'https://www.gov.uk/government/how-government-works',
#   'content': "The [Prime Minister](/government/ministers/prime-minister) is the leader of His Majesty’s Government and is ultimately responsible for all policy and decisions.\n\nThe Prime Minister also:\n\nThe Prime Minister is [The Rt Hon Sir Keir Starmer KCB KC MP](/government/people/keir-starmer).\n\n[Read more about the Prime Minister's Office, 10 Downing Street](/government/organisations/prime-ministers-office-10-downing-street) [...] ![The Rt Hon Sir Keir Starmer KCB KC MP](https://assets.publishing.service.gov.uk/media/66881349d9d35187868f454c/s465_53836009867_63fd6cdffe_b.jpg)\n\n### The Cabinet\n\nThe Cabinet is made up of the senior members of government. Every week during Parliament, members of the Cabinet (Secretaries of State from all departments and some other ministers) meet to discuss the most important issues for the government.\n\n[See who is in the Cabinet](/government/ministers) [...] In the UK, the Prime Minister leads the government with the support of the Cabinet and ministers. You can find out [who runs government](#who-runs-government) and [how government is run](#how-government-is-run), as well as learning about the [history of government](#history-uk-government).\n\n## Contents\n\n## Who runs government\n\n### The Prime Minister",
#   'score': 0.7077487}]

# %%
from langchain_experimental.utilities import PythonREPL

# %%
repl=PythonREPL()

# %%
code = """
x = 5
y = x * 2
print(y)
"""

# %%
repl.run(code)
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# '10\n'

# %%
from typing import Annotated

# %%
@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    
    result_str = f"Successfully executed:\n\`\`\`python\n{code}\n\`\`\`\nStdout: {result}"
    return (
        result_str + "\n\nIf you have completed all tasks, respond with FINAL ANSWER."
    )

# %%
python_repl_tool
# Out:
# StructuredTool(name='python_repl_tool', description='Use this to execute python code. If you want to see the output of a value,\n    you should print it out with `print(...)`. This is visible to the user.', args_schema=<class 'langchain_core.utils.pydantic.python_repl_tool'>, func=<function python_repl_tool at 0x000001BA8E116DD0>)

# %%
print(python_repl_tool.invoke(code))
# Out:
# Successfully executed:
# \`\`\`python
#
# x = 5
# y = x * 2
# print(y)
#
# \`\`\`
# Stdout: 10
#
#
# If you have completed all tasks, respond with FINAL ANSWER.

# %%
print(python_repl_tool.invoke(code))
# Out:
# Successfully executed:
# \`\`\`python
#
# x = 5
# y = x * 2
# print(y)
#
# \`\`\`
# Stdout: 10
#
#
# If you have completed all tasks, respond with FINAL ANSWER.

# %%
def make_system_prompt(instruction:str)->str:
    return  (
        "You are a helpful AI assistant, collaborating with other assistants."
        " Use the provided tools to progress towards answering the question."
        " If you are unable to fully answer, that's OK, another assistant with different tools "
        " will help where you left off. Execute what you can to make progress."
        " If you or any of the other assistants have the final answer or deliverable,"
        " prefix your response with FINAL ANSWER so the team knows to stop."
        f"\n{instruction}"
    )

# %%
make_system_prompt("You can only do research. You are working with a chart generator colleague.")
# Out:
# "You are a helpful AI assistant, collaborating with other assistants. Use the provided tools to progress towards answering the question. If you are unable to fully answer, that's OK, another assistant with different tools  will help where you left off. Execute what you can to make progress. If you or any of the other assistants have the final answer or deliverable, prefix your response with FINAL ANSWER so the team knows to stop.\nYou can only do research. You are working with a chart generator colleague."

# %% [markdown]
# "You are a helpful AI assistant, collaborating with other assistants. Use the provided tools to progress towards answering the question. If you are unable to fully answer, that's OK, another assistant with different tools  will help where you left off. Execute what you can to make progress. If you or any of the other assistants have the final answer or deliverable, prefix your response with FINAL ANSWER so the team knows to stop.\nYou can only do research. You are working with a chart generator colleague."

# %%
from langchain_core.messages import BaseMessage, HumanMessage

# %%
def get_next_node(last_message:BaseMessage, goto:str):
    if "FINAL ANSWER" in last_message.content:
        # Any agent decided the work is done
        return END
    return goto

# %%
#agent1
def research_node(state:MessagesState)->Command[Literal["chart_generator", END]]:
    research_agent=create_react_agent(
        llm,
        tools=[search_tool],
        prompt=make_system_prompt(
        "You can only do research. You are working with a chart generator colleague."
    ), 
        )
    
    result=research_agent.invoke(state)
    goto=get_next_node(result["messages"][-1],"chart_generator")
    result["messages"][-1] = HumanMessage(content=result["messages"][-1].content, name="researcher")
    return Command(update={"messages": result["messages"]},goto=goto)

# %%
#agent2
def chart_node(state:MessagesState)-> Command[Literal["researcher", END]]:
    chart_agent=create_react_agent(
        llm,
        tools=[python_repl_tool],
        prompt=make_system_prompt(
        "You can only generate charts. You are working with a researcher colleague."
    ),
        )
    result=chart_agent.invoke(state)
    goto=get_next_node(result["messages"][-1],"researcher")
    result["messages"][-1] = HumanMessage(content=result["messages"][-1].content, name="chart_generator")
    return Command(update={"messages": result["messages"]},goto=goto)

# %%
workflow = StateGraph(MessagesState)
workflow.add_node("researcher", research_node)
workflow.add_node("chart_generator", chart_node)

workflow.add_edge(START, "researcher")
app = workflow.compile()

# %%
workflow.compile()

# %%
app.invoke({"messages": [("user","get the UK's GDP over the past 3 years, then make a line chart of it.Once you make the chart, finish.")],})
# Out:
# {'messages': [HumanMessage(content="get the UK's GDP over the past 3 years, then make a line chart of it.Once you make the chart, finish.", additional_kwargs={}, response_metadata={}, id='a7eaefa5-4742-407d-918c-9bac29f82d8d'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_LcZXw6vsx7CJ6QKj9tsU0jwA', 'function': {'arguments': '{"query": "UK GDP 2020"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_8l9PHCvDcr52loCLcOjm6zWi', 'function': {'arguments': '{"query": "UK GDP 2021"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_itz5fjc3x9AEKATTYf09TIVP', 'function': {'arguments': '{"query": "UK GDP 2022"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 205, 'total_tokens': 287, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGqkyocHCAMiyPghOkJbBFwZjHzk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--5bf73e62-6bdf-4c55-a078-c24a9369f150-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2020'}, 'id': 'call_LcZXw6vsx7CJ6QKj9tsU0jwA', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2021'}, 'id': 'call_8l9PHCvDcr52loCLcOjm6zWi', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2022'}, 'id': 'call_itz5fjc3x9AEKATTYf09TIVP', 'type': 'tool_call'}], usage_metadata={'input_tokens': 205, 'output_tokens': 82, 'total_tokens': 287, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "U.K. GDP | Historical Chart & Data - Macrotrends", "url": "https://www.macrotrends.net/global-metrics/countries/gbr/united-kingdom/gdp-gross-domestic-product", "content": "*   U.K. gdp for 2023 was **$3,340.03B**, a **8.13% increase** from 2022.\\n*   U.K. gdp for 2022 was **$3,088.84B**, a **1.68% decline** from 2021.\\n*   U.K. gdp for 2021 was **$3,141.51B**, a **16.45% increase** from 2020.\\n*   U.K. gdp for 2020 was **$2,697.81B**, a **5.39% decline** from 2019.\\n\\n \\n\\n\xa0\xa0**Download Historical Data**\xa0\xa0 \xa0\xa0**Save as Image**\\n\\nData Source: [World Bank](http://datatopics.worldbank.org/world-development-indicators/)  \\n  \\nMLA Citation: [...] | U.K. GDP - Historical Data |\\n| --- |\\n| Year | GDP | Per Capita | Growth |\\n| --- | --- | --- | --- |\\n| 2023 | $3,340.03B | $48,867 | 0.10% |\\n| 2022 | $3,088.84B | $45,564 | 4.35% |\\n| 2021 | $3,141.51B | $46,870 | 8.67% |\\n| 2020 | $2,697.81B | $40,217 | \\\\-10.36% |\\n| 2019 | $2,851.41B | $42,663 | 1.64% |\\n| 2018 | $2,871.34B | $43,204 | 1.40% |\\n| 2017 | $2,680.15B | $40,572 | 2.66% |\\n| 2016 | $2,689.11B | $40,985 | 1.92% |\\n| 2015 | $2,927.91B | $44,964 | 2.22% | [...] | [United Kingdom](https://www.macrotrends.net/global-metrics/countries/GBR/united-kingdom/gdp-gross-domestic-product) | $3,340.03B |\\n| [France](https://www.macrotrends.net/global-metrics/countries/FRA/france/gdp-gross-domestic-product) | $3,030.90B |\\n| [Italy](https://www.macrotrends.net/global-metrics/countries/ITA/italy/gdp-gross-domestic-product) | $2,254.85B |\\n| [Canada](https://www.macrotrends.net/global-metrics/countries/CAN/canada/gdp-gross-domestic-product) | $2,140.09B |", "score": 0.8591094}, {"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "The gross domestic product of the United Kingdom was around 2.56 trillion British pounds, an increase when compared to the previous year, when UK GDP amounted to about 2.54 trillion pounds. The significant drop in GDP visible in 2020 was due to the COVID-19 pandemic, with the smaller declines in 2008 and 2009 because of the global financial crisis of the late 2000s.\\n\\n## Low growth problem in the UK [...] | Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 |", "score": 0.8585411}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| Rank | Country | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\n| --- | --- | --- |\\n| 1 | [England](https://en.wikipedia.org/wiki/England \\"England\\") | £32,866 ($42136) |\\n| 2 | [Scotland](https://en.wikipedia.org/wiki/Scotland \\"Scotland\\") | £29,629 ($37986) |\\n| 3 | [Northern Ireland](https://en.wikipedia.org/wiki/Northern_Ireland \\"Northern Ireland\\") | £25,575 ($32788) | [...] | Rank | Region | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\n| --- | --- | --- |\\n| 1 | [London](https://en.wikipedia.org/wiki/London \\"London\\") | £55,974 ($71762) |\\n| 2 | [South East England](https://en.wikipedia.org/wiki/South_East_England \\"South East England\\") | £34,516 ($44251) |\\n| 3 | [East of England](https://en.wikipedia.org/wiki/East_of_England \\"East of England\\") | £29,176 ($37405) | [...] | 2020 | ![Image 361: Decrease](https://upload.wikimedia.org/wikipedia/commons/thumb/e ...
#   ToolMessage(content='[{"title": "U.K. GDP | Historical Chart & Data - Macrotrends", "url": "https://www.macrotrends.net/global-metrics/countries/gbr/united-kingdom/gdp-gross-domestic-product", "content": "*   U.K. gdp for 2023 was **$3,340.03B**, a **8.13% increase** from 2022.\\n*   U.K. gdp for 2022 was **$3,088.84B**, a **1.68% decline** from 2021.\\n*   U.K. gdp for 2021 was **$3,141.51B**, a **16.45% increase** from 2020.\\n*   U.K. gdp for 2020 was **$2,697.81B**, a **5.39% decline** from 2019.\\n\\n \\n\\n\xa0\xa0**Download Historical Data**\xa0\xa0 \xa0\xa0**Save as Image**\\n\\nData Source: [World Bank](http://datatopics.worldbank.org/world-development-indicators/)  \\n  \\nMLA Citation: [...] | U.K. GDP - Historical Data |\\n| --- |\\n| Year | GDP | Per Capita | Growth |\\n| --- | --- | --- | --- |\\n| 2023 | $3,340.03B | $48,867 | 0.10% |\\n| 2022 | $3,088.84B | $45,564 | 4.35% |\\n| 2021 | $3,141.51B | $46,870 | 8.67% |\\n| 2020 | $2,697.81B | $40,217 | \\\\-10.36% |\\n| 2019 | $2,851.41B | $42,663 | 1.64% |\\n| 2018 | $2,871.34B | $43,204 | 1.40% |\\n| 2017 | $2,680.15B | $40,572 | 2.66% |\\n| 2016 | $2,689.11B | $40,985 | 1.92% |\\n| 2015 | $2,927.91B | $44,964 | 2.22% | [...] | [United Kingdom](https://www.macrotrends.net/global-metrics/countries/GBR/united-kingdom/gdp-gross-domestic-product) | $3,340.03B |\\n| [France](https://www.macrotrends.net/global-metrics/countries/FRA/france/gdp-gross-domestic-product) | $3,030.90B |\\n| [Italy](https://www.macrotrends.net/global-metrics/countries/ITA/italy/gdp-gross-domestic-product) | $2,254.85B |\\n| [Canada](https://www.macrotrends.net/global-metrics/countries/CAN/canada/gdp-gross-domestic-product) | $2,140.09B |", "score": 0.8861155}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| 2021 | ![Image 369: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,402.7 | ![Image 370: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)50,522.7 | ![Image 371: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,187.6 | ![Image 372: [...] In August 2023, the [ONS](https://en.wikipedia.org/wiki/Office_for_National_Statistics \\"Office for National Statistics\\") revised its analysis of Britain\'s economic performance and said that Britain\'s GDP had surpassed its pre-COVID-19 size in the final quarter of 2021, a much earlier recovery from the pandemic than previously estimated and ahead of other big European countries. The British economy was 0.6% larger in the fourth quarter of 2021 than in the final quarter of 2019, compared with an [...] Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)21,499.6 | ![Image 157: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3.4% | ![Image 158: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)2.0% | ![Image 159: Positive", "score": 0.7555112}, {"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "| Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 | [...] The gross domestic product of the United Kingdom was around 2.56 trillion British pounds, an increase when compared to the previous yea ...
#   ToolMessage(content='[{"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "| Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 | [...] This statistic is using original data from the Office for National Statistics and includes copyright material from © Crown, licensed under the\xa0[Open Government License v3.0](https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).  \\n  \\n\\\\*GDP is displayed in real terms (seasonally adjusted chained volume measure with 2022 as the reference year) [...] This statistic is using original data from the Office for National Statistics and includes copyright material from © Crown, licensed under the\xa0[Open Government License v3.0](https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).  \\n  \\n\\\\*GDP is displayed in real terms (seasonally adjusted chained volume measure with 2022 as the reference year)\\n\\n## Other statistics on the topic [The UK economy](/topics/6500/the-british-economy/)", "score": 0.7946564}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| 2022 | ![Image 377: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,776.0 | ![Image 378: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)55,862.1 | ![Image 379: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,198.5 | ![Image 380: [...] *   [6 Economic variation within the United Kingdom](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#Economic_variation_within_the_United_Kingdom)Toggle Economic variation within the United Kingdom subsection\\n    *   [6.1 Gross domestic product (2022)](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#Gross_domestic_product_(2022))\\n        *   [6.1.1 By English region](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#By_English_region) [...] Within the United Kingdom, [England](https://en.wikipedia.org/wiki/Economy_of_England \\"Economy of England\\") has the largest constituent economy measured by [gross domestic product](https://en.wikipedia.org/wiki/Gross_domestic_product \\"Gross domestic product\\") (GDP) according to the figures provided by the [Office for National Statistics](https://en.wikipedia.org/wiki/Office_for_National_Statistics \\"Office for National Statistics\\") (ONS) for the year 2022, whilst [Northern", "score": 0.7760977}, {"title": "Gross Domestic Product (GDP) - Office for National Statistics", "url": "https://www.ons.gov.uk/economy/grossdomesticproductgdp", "content": "Estimates of short-term indicators of investment in non-financial assets; business investment, and asset and sector breakdowns of total gross fixed capital formation.\\n\\n*   #### [GDP, UK regions and countries: July to September 2022](https://www.ons.gov.uk/economy/grossdomesticproductgdp/bulletins/gdpukregionsandcountries/julytoseptember2022)", "score": 0.66203266}]', name='tavily_search_results_json', id='38a8ef59-0484-4115-a862-39fa6cfaedf1', tool_call_id='call_itz5fjc3x9AEKATTYf09TIVP', artifact={'query': 'UK GDP 2022', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/', 'title': 'UK GDP 2024 - Statista', 'content': '| Character ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_5eHcL3WBJlOJaoGfvdz8gpAl', 'function': {'arguments': '{"query":"UK GDP in USD for the years 2022, 2021, and 2020"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 4859, 'total_tokens': 4895, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGqrZCdg4bWBHXVpqVY6R49sIfLV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--112cc3bd-7d0e-4ce0-b3f8-5eabc922c8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP in USD for the years 2022, 2021, and 2020'}, 'id': 'call_5eHcL3WBJlOJaoGfvdz8gpAl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 4859, 'output_tokens': 36, 'total_tokens': 4895, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "Gross Domestic Product for United Kingdom - FRED", "url": "https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB", "content": "<table id=\\"recent-obs\\" class=\\"table table-condensed\\"><tbody><tr><td align=\\"right\\">2023:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,380,854,520,809.5400</td><td>&#160;</td></tr><tr><td align=\\"right\\">2022:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,114,042,471,144.3900</td><td>&#160;</td></tr><tr><td align=\\"right\\">2021:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,143,323,050,707.2600</td><td>&#160;</td></tr><tr><td align=\\"right\\">2020:&#160;</td><td align=\\"right\\" [...] [EDIT Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[ADD Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[FORMAT](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)\\n\\nLine\xa01\\n\\n(a)\xa0Gross Domestic Product for United Kingdom,\xa0Current U.S. Dollars,\xa0Not Seasonally Adjusted\xa0(MKTGDPGBA646NWDB)\\n\\nUnits\\n\\n  \\n\\nSelect a date that will equal 100 for your custom index:\\n\\nU.S. recession:or\xa0\xa0**Enter date as YYYY-MM-DD** [...] official exchange rate does not reflect the rate effectively applied to actual foreign exchange transactions, an alternative conversion factor is used.", "score": 0.9006087}, {"title": "United Kingdom GDP - Worldometer", "url": "https://www.worldometers.info/gdp/uk-gdp/", "content": "| Year | GDP Nominal  \\n(Current USD) | GDP Real  \\n(Inflation adj.) | GDP  \\nChange | GDP per  \\ncapita | Pop.  \\nChange | Population |\\n| --- | --- | --- | --- | --- | --- | --- |\\n| 2023 | $3,380,850,000,000 | $3,234,500,000,000 | 0.34% | $47,093 | 0.74% | 68,682,962 |\\n| 2022 | $3,114,040,000,000 | $3,223,550,000,000 | 4.84% | $47,280 | 0.75% | 68,179,315 |\\n| 2021 | $3,143,320,000,000 | $3,074,760,000,000 | 8.58% | $45,438 | 0.47% | 67,668,792 | [...] | 2008 | 2,929,410,000,000 |\\n| 2009 | 2,412,840,000,000 |\\n| 2010 | 2,485,480,000,000 |\\n| 2011 | 2,663,810,000,000 |\\n| 2012 | 2,707,090,000,000 |\\n| 2013 | 2,784,850,000,000 |\\n| 2014 | 3,064,710,000,000 |\\n| 2015 | 2,927,910,000,000 |\\n| 2016 | 2,689,110,000,000 |\\n| 2017 | 2,680,150,000,000 |\\n| 2018 | 2,871,340,000,000 |\\n| 2019 | 2,851,410,000,000 |\\n| 2020 | 2,696,780,000,000 |\\n| 2021 | 3,143,320,000,000 |\\n| 2022 | 3,114,040,000,000 |\\n| 2023 | 3,380,850,000,000 | [...] | 2019 | 1.62% |\\n| 2020 | \\\\-10.30% |\\n| 2021 | 8.58% |\\n| 2022 | 4.84% |\\n| 2023 | 0.34% |", "score": 0.89121616}, {"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "| Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 |", "score": 0.7900289}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| 2022 | ![Image 377: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,776.0 | ![Image 378: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)55,862.1 | ![Image 379: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,198.5 | ![Image 380: [...] | Rank | Country | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\ ...
#   AIMessage(content="The GDP of the United Kingdom over the past three years in USD (nominal terms) was:\n\n- 2020: $2,696.78 billion\n- 2021: $3,143.32 billion\n- 2022: $3,114.04 billion\n\nThese figures reflect nominal GDP values in current USD. Now I'll proceed to create a line chart with this data.", additional_kwargs={'tool_calls': [{'id': 'call_cLHSnWBNfInddZdlAqk6Yneo', 'function': {'arguments': '{"query":"UK GDP 2022, 2021, and 2020 real terms USD"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 6726, 'total_tokens': 6842, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4864}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGqwujkpaiPcUIT74LWmAAVGWAuB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--07b4c108-9061-4e2c-82f7-dfbf88c63059-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2022, 2021, and 2020 real terms USD'}, 'id': 'call_cLHSnWBNfInddZdlAqk6Yneo', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6726, 'output_tokens': 116, 'total_tokens': 6842, 'input_token_details': {'audio': 0, 'cache_read': 4864}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "Gross Domestic Product for United Kingdom - FRED", "url": "https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB", "content": "<table id=\\"recent-obs\\" class=\\"table table-condensed\\"><tbody><tr><td align=\\"right\\">2023:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,380,854,520,809.5400</td><td>&#160;</td></tr><tr><td align=\\"right\\">2022:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,114,042,471,144.3900</td><td>&#160;</td></tr><tr><td align=\\"right\\">2021:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,143,323,050,707.2600</td><td>&#160;</td></tr><tr><td align=\\"right\\">2020:&#160;</td><td align=\\"right\\" [...] official exchange rate does not reflect the rate effectively applied to actual foreign exchange transactions, an alternative conversion factor is used. [...] [EDIT Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[ADD Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[FORMAT](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)\\n\\nLine\xa01\\n\\n(a)\xa0Gross Domestic Product for United Kingdom,\xa0Current U.S. Dollars,\xa0Not Seasonally Adjusted\xa0(MKTGDPGBA646NWDB)\\n\\nUnits\\n\\n  \\n\\nSelect a date that will equal 100 for your custom index:\\n\\nU.S. recession:or\xa0\xa0**Enter date as YYYY-MM-DD**", "score": 0.89302075}, {"title": "United Kingdom GDP - Worldometer", "url": "https://www.worldometers.info/gdp/uk-gdp/", "content": "| Year | GDP Nominal  \\n(Current USD) | GDP Real  \\n(Inflation adj.) | GDP  \\nChange | GDP per  \\ncapita | Pop.  \\nChange | Population |\\n| --- | --- | --- | --- | --- | --- | --- |\\n| 2023 | $3,380,850,000,000 | $3,234,500,000,000 | 0.34% | $47,093 | 0.74% | 68,682,962 |\\n| 2022 | $3,114,040,000,000 | $3,223,550,000,000 | 4.84% | $47,280 | 0.75% | 68,179,315 |\\n| 2021 | $3,143,320,000,000 | $3,074,760,000,000 | 8.58% | $45,438 | 0.47% | 67,668,792 | [...] | 2008 | 2,929,410,000,000 |\\n| 2009 | 2,412,840,000,000 |\\n| 2010 | 2,485,480,000,000 |\\n| 2011 | 2,663,810,000,000 |\\n| 2012 | 2,707,090,000,000 |\\n| 2013 | 2,784,850,000,000 |\\n| 2014 | 3,064,710,000,000 |\\n| 2015 | 2,927,910,000,000 |\\n| 2016 | 2,689,110,000,000 |\\n| 2017 | 2,680,150,000,000 |\\n| 2018 | 2,871,340,000,000 |\\n| 2019 | 2,851,410,000,000 |\\n| 2020 | 2,696,780,000,000 |\\n| 2021 | 3,143,320,000,000 |\\n| 2022 | 3,114,040,000,000 |\\n| 2023 | 3,380,850,000,000 | [...] | 2019 | 1.62% |\\n| 2020 | \\\\-10.30% |\\n| 2021 | 8.58% |\\n| 2022 | 4.84% |\\n| 2023 | 0.34% |", "score": 0.8755427}, {"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "| Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 |", "score": 0.71496695}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| Rank | Country | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\n| --- | --- | --- |\\n| 1 | [England](https://en.wikipedia.org/wiki/England \\"England\\") | £32,866 ($42136) |\\n| 2 | [Scotland](https://en.wikipedia.org/wiki/Scotland \\"Scotland\\") | £29,629 ($37986) |\\n| 3 | [Northern Ireland](https://en.wikipedia.org/wiki/Northern_Ireland \\"Northern Ireland\\") | £25,575 ($32788) | [...] | 2022 | ![Image 377: Increase](https://upload.wikimedia.org/wikipedia/commons/ ...
#   AIMessage(content='The real (inflation-adjusted) GDP figures for the United Kingdom in USD for the past three years are as follows:\n\n- 2020: $2,696.78 billion\n- 2021: $3,074.76 billion\n- 2022: $3,223.55 billion\n\nI will now create a line chart to visualize this data.', additional_kwargs={'tool_calls': [{'id': 'call_11gaQDz4Fr4S1LfAGXZrVRFo', 'function': {'arguments': '{"query":"UK GDP 2020 to 2022 in USD"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 8710, 'total_tokens': 8815, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 6784}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGr3B0zrUKtGVUhyr16A0xzZ4NvG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--21388149-683f-4956-8e3e-8a6983a54b80-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2020 to 2022 in USD'}, 'id': 'call_11gaQDz4Fr4S1LfAGXZrVRFo', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8710, 'output_tokens': 105, 'total_tokens': 8815, 'input_token_details': {'audio': 0, 'cache_read': 6784}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "Gross Domestic Product for United Kingdom - FRED", "url": "https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB", "content": "<table id=\\"recent-obs\\" class=\\"table table-condensed\\"><tbody><tr><td align=\\"right\\">2023:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,380,854,520,809.5400</td><td>&#160;</td></tr><tr><td align=\\"right\\">2022:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,114,042,471,144.3900</td><td>&#160;</td></tr><tr><td align=\\"right\\">2021:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,143,323,050,707.2600</td><td>&#160;</td></tr><tr><td align=\\"right\\">2020:&#160;</td><td align=\\"right\\" [...] [EDIT Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[ADD Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[FORMAT](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)\\n\\nLine\xa01\\n\\n(a)\xa0Gross Domestic Product for United Kingdom,\xa0Current U.S. Dollars,\xa0Not Seasonally Adjusted\xa0(MKTGDPGBA646NWDB)\\n\\nUnits\\n\\n  \\n\\nSelect a date that will equal 100 for your custom index:\\n\\nU.S. recession:or\xa0\xa0**Enter date as YYYY-MM-DD** [...] official exchange rate does not reflect the rate effectively applied to actual foreign exchange transactions, an alternative conversion factor is used.", "score": 0.77055156}, {"title": "United Kingdom GDP - Worldometer", "url": "https://www.worldometers.info/gdp/uk-gdp/", "content": "| 2008 | 2,929,410,000,000 |\\n| 2009 | 2,412,840,000,000 |\\n| 2010 | 2,485,480,000,000 |\\n| 2011 | 2,663,810,000,000 |\\n| 2012 | 2,707,090,000,000 |\\n| 2013 | 2,784,850,000,000 |\\n| 2014 | 3,064,710,000,000 |\\n| 2015 | 2,927,910,000,000 |\\n| 2016 | 2,689,110,000,000 |\\n| 2017 | 2,680,150,000,000 |\\n| 2018 | 2,871,340,000,000 |\\n| 2019 | 2,851,410,000,000 |\\n| 2020 | 2,696,780,000,000 |\\n| 2021 | 3,143,320,000,000 |\\n| 2022 | 3,114,040,000,000 |\\n| 2023 | 3,380,850,000,000 | [...] | Year | GDP Nominal  \\n(Current USD) | GDP Real  \\n(Inflation adj.) | GDP  \\nChange | GDP per  \\ncapita | Pop.  \\nChange | Population |\\n| --- | --- | --- | --- | --- | --- | --- |\\n| 2023 | $3,380,850,000,000 | $3,234,500,000,000 | 0.34% | $47,093 | 0.74% | 68,682,962 |\\n| 2022 | $3,114,040,000,000 | $3,223,550,000,000 | 4.84% | $47,280 | 0.75% | 68,179,315 |\\n| 2021 | $3,143,320,000,000 | $3,074,760,000,000 | 8.58% | $45,438 | 0.47% | 67,668,792 | [...] | 2019 | 1.62% |\\n| 2020 | \\\\-10.30% |\\n| 2021 | 8.58% |\\n| 2022 | 4.84% |\\n| 2023 | 0.34% |", "score": 0.76826453}, {"title": "Economy of the United Kingdom - Wikipedia", "url": "https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom", "content": "| Rank | Country | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\n| --- | --- | --- |\\n| 1 | [England](https://en.wikipedia.org/wiki/England \\"England\\") | £32,866 ($42136) |\\n| 2 | [Scotland](https://en.wikipedia.org/wiki/Scotland \\"Scotland\\") | £29,629 ($37986) |\\n| 3 | [Northern Ireland](https://en.wikipedia.org/wiki/Northern_Ireland \\"Northern Ireland\\") | £25,575 ($32788) | [...] | Rank | Region | GVA per head, 2020[[245]](https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom#cite_note-GVA_ONS20-257) |\\n| --- | --- | --- |\\n| 1 | [London](https://en.wikipedia.org/wiki/London \\"London\\") | £55,974 ($71762) |\\n| 2 | [South East England](https://en.wikipedia.org/wiki/South_East_England \\"South East England\\") | £34,516 ($44251) |\\n| 3 | [East of England](https://en.wikipedia.org/wiki/East_of_England \\"East of England\\") | £29,176 ($37405) | [...] | 2021 | ![Image 369: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)3,402.7 | ![Image 370: Increase](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png)50,522.7 | ![Image ...
#   AIMessage(content="The data on the UK's GDP for the years 2020, 2021, and 2022 in current USD is already cleared:\n\n- 2020: $2,696.78 billion\n- 2021: $3,143.32 billion\n- 2022: $3,114.04 billion\n\nI will proceed with creating a line chart to visualize this information.", additional_kwargs={'tool_calls': [{'id': 'call_oTRCfdubMnFkp2mfHTRqcoTn', 'function': {'arguments': '{"query":"UK GDP values in USD from 2020 to 2022"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 10647, 'total_tokens': 10758, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 8704}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGrBvKYT3k1kP1u0rdaIzI2IXnZ8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--d8ec0cd2-90bf-464c-a968-eee137ca94c3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP values in USD from 2020 to 2022'}, 'id': 'call_oTRCfdubMnFkp2mfHTRqcoTn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 10647, 'output_tokens': 111, 'total_tokens': 10758, 'input_token_details': {'audio': 0, 'cache_read': 8704}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "U.K. GDP | Historical Chart & Data - Macrotrends", "url": "https://www.macrotrends.net/global-metrics/countries/gbr/united-kingdom/gdp-gross-domestic-product", "content": "*   U.K. gdp for 2023 was **$3,340.03B**, a **8.13% increase** from 2022.\\n*   U.K. gdp for 2022 was **$3,088.84B**, a **1.68% decline** from 2021.\\n*   U.K. gdp for 2021 was **$3,141.51B**, a **16.45% increase** from 2020.\\n*   U.K. gdp for 2020 was **$2,697.81B**, a **5.39% decline** from 2019.\\n\\n \\n\\n\xa0\xa0**Download Historical Data**\xa0\xa0 \xa0\xa0**Save as Image**\\n\\nData Source: [World Bank](http://datatopics.worldbank.org/world-development-indicators/)  \\n  \\nMLA Citation: [...] | U.K. GDP - Historical Data |\\n| --- |\\n| Year | GDP | Per Capita | Growth |\\n| --- | --- | --- | --- |\\n| 2023 | $3,340.03B | $48,867 | 0.10% |\\n| 2022 | $3,088.84B | $45,564 | 4.35% |\\n| 2021 | $3,141.51B | $46,870 | 8.67% |\\n| 2020 | $2,697.81B | $40,217 | \\\\-10.36% |\\n| 2019 | $2,851.41B | $42,663 | 1.64% |\\n| 2018 | $2,871.34B | $43,204 | 1.40% |\\n| 2017 | $2,680.15B | $40,572 | 2.66% |\\n| 2016 | $2,689.11B | $40,985 | 1.92% |\\n| 2015 | $2,927.91B | $44,964 | 2.22% | [...] | [United Kingdom](https://www.macrotrends.net/global-metrics/countries/GBR/united-kingdom/gdp-gross-domestic-product) | $3,340.03B |\\n| [France](https://www.macrotrends.net/global-metrics/countries/FRA/france/gdp-gross-domestic-product) | $3,030.90B |\\n| [Italy](https://www.macrotrends.net/global-metrics/countries/ITA/italy/gdp-gross-domestic-product) | $2,254.85B |\\n| [Canada](https://www.macrotrends.net/global-metrics/countries/CAN/canada/gdp-gross-domestic-product) | $2,140.09B |", "score": 0.8745175}, {"title": "Gross Domestic Product for United Kingdom - FRED", "url": "https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB", "content": "<table id=\\"recent-obs\\" class=\\"table table-condensed\\"><tbody><tr><td align=\\"right\\">2023:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,380,854,520,809.5400</td><td>&#160;</td></tr><tr><td align=\\"right\\">2022:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,114,042,471,144.3900</td><td>&#160;</td></tr><tr><td align=\\"right\\">2021:&#160;</td><td align=\\"right\\" class=\\"series-obs value\\">3,143,323,050,707.2600</td><td>&#160;</td></tr><tr><td align=\\"right\\">2020:&#160;</td><td align=\\"right\\" [...] [EDIT Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[ADD Line](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[FORMAT](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)[](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)\\n\\nLine\xa01\\n\\n(a)\xa0Gross Domestic Product for United Kingdom,\xa0Current U.S. Dollars,\xa0Not Seasonally Adjusted\xa0(MKTGDPGBA646NWDB)\\n\\nUnits\\n\\n  \\n\\nSelect a date that will equal 100 for your custom index:\\n\\nU.S. recession:or\xa0\xa0**Enter date as YYYY-MM-DD** [...] Units:\\n\\nCurrent U.S. Dollars,\\n\\nNot Seasonally Adjusted\\n\\nFrequency:\\n\\nAnnual\\n\\n1Y5Y10YMax[](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#)\\n\\nFromto\\n\\nDate:\\n\\nEdit Graph\xa0\xa0[Edit Map](https://fred.stlouisfed.org/series/MKTGDPGBA646NWDB#0)\xa0\xa0\xa0\\n\\nDownload\\n\\n\xa0\xa0View Map\xa0\xa0\xa0\\n\\n          \\n\\n[](https://fred.stlouisfed.org/)", "score": 0.83678174}, {"title": "United Kingdom GDP - Worldometer", "url": "https://www.worldometers.info/gdp/uk-gdp/", "content": "| 2008 | 2,929,410,000,000 |\\n| 2009 | 2,412,840,000,000 |\\n| 2010 | 2,485,480,000,000 |\\n| 2011 | 2,663,810,000,000 |\\n| 2012 | 2,707,090,000,000 |\\n| 2013 | 2,784,850,000,000 |\\n| 2014 | 3,064,710,000,000 |\\n| 2015 | 2,927,910,000,000 |\\n| 2016 | 2,689,110,000,000 |\\n| 2017 | 2,680,150,000,000 |\\n| 2018 | 2,871,340,000,000 |\\n| 2019 | 2,851,410,000,000 |\\n| 2020 | 2,696,780,000,000 |\\n| 2021 | 3,143,320,000,000 |\\n| 2022 | 3,114,040,000,000 |\\n| 2023 | 3,380,850,000,000 | [...] | Year | GDP Nomin ...
#   AIMessage(content='Based on the information I have retrieved, here is a verification of the UK GDP figures in USD for 2020, 2021, and 2022:\n\n- 2020: $2,696.78 billion\n- 2021: $3,143.32 billion\n- 2022: $3,114.04 billion\n\nI will create the line chart using this data now.', additional_kwargs={'tool_calls': [{'id': 'call_UzCRI29DbdfIxOkc0sap5RfD', 'function': {'arguments': '{"query":"UK GDP 2020 to 2022 in USD visualization"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 13045, 'total_tokens': 13158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 10752}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGrFwow8kxd9LggVLs2w9JuxeG7z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--99ce4228-6bf1-42b9-bf15-991117bbe627-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2020 to 2022 in USD visualization'}, 'id': 'call_UzCRI29DbdfIxOkc0sap5RfD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 13045, 'output_tokens': 113, 'total_tokens': 13158, 'input_token_details': {'audio': 0, 'cache_read': 10752}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "U.K. GDP | Historical Chart & Data - Macrotrends", "url": "https://www.macrotrends.net/global-metrics/countries/gbr/united-kingdom/gdp-gross-domestic-product", "content": "*   U.K. gdp for 2023 was **$3,340.03B**, a **8.13% increase** from 2022.\\n*   U.K. gdp for 2022 was **$3,088.84B**, a **1.68% decline** from 2021.\\n*   U.K. gdp for 2021 was **$3,141.51B**, a **16.45% increase** from 2020.\\n*   U.K. gdp for 2020 was **$2,697.81B**, a **5.39% decline** from 2019.\\n\\n \\n\\n\xa0\xa0**Download Historical Data**\xa0\xa0 \xa0\xa0**Save as Image**\\n\\nData Source: [World Bank](http://datatopics.worldbank.org/world-development-indicators/)  \\n  \\nMLA Citation: [...] | U.K. GDP - Historical Data |\\n| --- |\\n| Year | GDP | Per Capita | Growth |\\n| --- | --- | --- | --- |\\n| 2023 | $3,340.03B | $48,867 | 0.10% |\\n| 2022 | $3,088.84B | $45,564 | 4.35% |\\n| 2021 | $3,141.51B | $46,870 | 8.67% |\\n| 2020 | $2,697.81B | $40,217 | \\\\-10.36% |\\n| 2019 | $2,851.41B | $42,663 | 1.64% |\\n| 2018 | $2,871.34B | $43,204 | 1.40% |\\n| 2017 | $2,680.15B | $40,572 | 2.66% |\\n| 2016 | $2,689.11B | $40,985 | 1.92% |\\n| 2015 | $2,927.91B | $44,964 | 2.22% | [...] | [United Kingdom](https://www.macrotrends.net/global-metrics/countries/GBR/united-kingdom/gdp-gross-domestic-product) | $3,340.03B |\\n| [France](https://www.macrotrends.net/global-metrics/countries/FRA/france/gdp-gross-domestic-product) | $3,030.90B |\\n| [Italy](https://www.macrotrends.net/global-metrics/countries/ITA/italy/gdp-gross-domestic-product) | $2,254.85B |\\n| [Canada](https://www.macrotrends.net/global-metrics/countries/CAN/canada/gdp-gross-domestic-product) | $2,140.09B |", "score": 0.8106142}, {"title": "United Kingdom GDP - Worldometer", "url": "https://www.worldometers.info/gdp/uk-gdp/", "content": "| 2008 | 2,929,410,000,000 |\\n| 2009 | 2,412,840,000,000 |\\n| 2010 | 2,485,480,000,000 |\\n| 2011 | 2,663,810,000,000 |\\n| 2012 | 2,707,090,000,000 |\\n| 2013 | 2,784,850,000,000 |\\n| 2014 | 3,064,710,000,000 |\\n| 2015 | 2,927,910,000,000 |\\n| 2016 | 2,689,110,000,000 |\\n| 2017 | 2,680,150,000,000 |\\n| 2018 | 2,871,340,000,000 |\\n| 2019 | 2,851,410,000,000 |\\n| 2020 | 2,696,780,000,000 |\\n| 2021 | 3,143,320,000,000 |\\n| 2022 | 3,114,040,000,000 |\\n| 2023 | 3,380,850,000,000 | [...] | Year | GDP Nominal  \\n(Current USD) | GDP Real  \\n(Inflation adj.) | GDP  \\nChange | GDP per  \\ncapita | Pop.  \\nChange | Population |\\n| --- | --- | --- | --- | --- | --- | --- |\\n| 2023 | $3,380,850,000,000 | $3,234,500,000,000 | 0.34% | $47,093 | 0.74% | 68,682,962 |\\n| 2022 | $3,114,040,000,000 | $3,223,550,000,000 | 4.84% | $47,280 | 0.75% | 68,179,315 |\\n| 2021 | $3,143,320,000,000 | $3,074,760,000,000 | 8.58% | $45,438 | 0.47% | 67,668,792 | [...] | 2019 | 1.62% |\\n| 2020 | \\\\-10.30% |\\n| 2021 | 8.58% |\\n| 2022 | 4.84% |\\n| 2023 | 0.34% |", "score": 0.6944897}, {"title": "UK GDP Quarterly Analysis - YCharts", "url": "https://ycharts.com/indicators/uk_gdp_sa_currencys", "content": "TGvhEUpwdT%2FU26poSEyaR5d3GcwylykBwlAI6oO0msjE%2FtT3CS1b9kkq2qgkz%2FFvuUEFg6DHEIc6xeQ9wS5taL4MSz09MqoBCtwGZxKty1jrnNdZYP8qxPT15l4CDbXyieLpETN6xSToHdp7dqWcjTu4SPtswICckHO6Pjqp%2B8wUTCCRFFsF4XpWBddzGkpj9EaN1EBOWYNB1GiXpTaSZSEQAjbFdDCopZvABjqxAVYntPI62g%2B2G9%2FytqT8qmfd6F1h3BYWhUQTBEHTBkuJr7UqHAzQGK8SmdaDkOb%2BQdeBWhgGK80SoO%2B8np0gaQDB9Fk04QVfblNZpW1wPOGIoVer1t0teLqH%2FlOVD%2FPgguE5NMseWLR9cuxSVV4Wdp5wg0i1UzOUCxt2QSVqH9J6pQ2drZkfjra9JR7bRmVunW2TnkRp9B88q0DIauud9Nq6j9s8FTXjbdx9ohKImVM0rg%3D%3D&Exp [...] .webp?AWSAccessKeyId=ASIA3WEVRVL2UGMQTA3H&Signature=FSMv%2B2T8my6jxMWoLm6qr%2B2HmAU%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEEAaCXVzLWVhc3QtMSJHMEUCIQDAODbgfn%2FMUuR%2FQDi0j1IKSULWq0PuK%2Bl3zV4F%2FqVJPAIgP2LFMJK1UVuTJv5Fu4cOIf%2Fh3obGJGIg877uwufaod0qugUIyP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw4MDM0NzI1MTc4NzciDCZSItsJz3oPWtIAlyqOBftfyPC7FPchYaZX0XNKMFAV4N5YNa%2FTzDnPv1meXfyN5H6B2uLQmca9kTBf1nPR0SvWsNFSHlOc14bWq5nLODd0bF%2Fnz4fTUscdOMTQKmQs ...
#   AIMessage(content="Let's proceed to create a line chart with the confirmed GDP figures for the years 2020 to 2022 in USD:\n\n- 2020: $2,696.78 billion\n- 2021: $3,143.32 billion\n- 2022: $3,114.04 billion\n\nI'll forward this to my colleague to generate the chart.", additional_kwargs={'tool_calls': [{'id': 'call_9AbIHDTxBXHubmtcbS3ad6fX', 'function': {'arguments': '{"query":"UK GDP 2022, 2021, 2020 line chart"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 15795, 'total_tokens': 15903, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 13056}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BlGrj5118xEnCUvv2rKqhawIAEjGR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--90d4fe41-9b5c-464e-bde0-cbea8194b1b5-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'UK GDP 2022, 2021, 2020 line chart'}, 'id': 'call_9AbIHDTxBXHubmtcbS3ad6fX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 15795, 'output_tokens': 108, 'total_tokens': 15903, 'input_token_details': {'audio': 0, 'cache_read': 13056}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{"title": "U.K. GDP | Historical Chart & Data - Macrotrends", "url": "https://www.macrotrends.net/global-metrics/countries/gbr/united-kingdom/gdp-gross-domestic-product", "content": "*   U.K. gdp for 2023 was **$3,340.03B**, a **8.13% increase** from 2022.\\n*   U.K. gdp for 2022 was **$3,088.84B**, a **1.68% decline** from 2021.\\n*   U.K. gdp for 2021 was **$3,141.51B**, a **16.45% increase** from 2020.\\n*   U.K. gdp for 2020 was **$2,697.81B**, a **5.39% decline** from 2019.\\n\\n \\n\\n\xa0\xa0**Download Historical Data**\xa0\xa0 \xa0\xa0**Save as Image**\\n\\nData Source: [World Bank](http://datatopics.worldbank.org/world-development-indicators/)  \\n  \\nMLA Citation: [...] | U.K. GDP - Historical Data |\\n| --- |\\n| Year | GDP | Per Capita | Growth |\\n| --- | --- | --- | --- |\\n| 2023 | $3,340.03B | $48,867 | 0.10% |\\n| 2022 | $3,088.84B | $45,564 | 4.35% |\\n| 2021 | $3,141.51B | $46,870 | 8.67% |\\n| 2020 | $2,697.81B | $40,217 | \\\\-10.36% |\\n| 2019 | $2,851.41B | $42,663 | 1.64% |\\n| 2018 | $2,871.34B | $43,204 | 1.40% |\\n| 2017 | $2,680.15B | $40,572 | 2.66% |\\n| 2016 | $2,689.11B | $40,985 | 1.92% |\\n| 2015 | $2,927.91B | $44,964 | 2.22% | [...] | [United Kingdom](https://www.macrotrends.net/global-metrics/countries/GBR/united-kingdom/gdp-gross-domestic-product) | $3,340.03B |\\n| [France](https://www.macrotrends.net/global-metrics/countries/FRA/france/gdp-gross-domestic-product) | $3,030.90B |\\n| [Italy](https://www.macrotrends.net/global-metrics/countries/ITA/italy/gdp-gross-domestic-product) | $2,254.85B |\\n| [Canada](https://www.macrotrends.net/global-metrics/countries/CAN/canada/gdp-gross-domestic-product) | $2,140.09B |", "score": 0.92700076}, {"title": "Constant GDP per capita for the United Kingdom - FRED", "url": "https://fred.stlouisfed.org/series/NYGDPPCAPKDGBR", "content": "# Constant GDP per capita for the United Kingdom (NYGDPPCAPKDGBR)\\n\\nObservations\\n\\n2023: 47,322.66822 |\\n2010 U.S. Dollars, Not Seasonally Adjusted |\\nAnnual\\n\\nUpdated:\\nDec 17, 2024\\n2:10 PM CST\\n\\nNext Release Date:\\nNot Available\\n\\nObservations\\n\\n|  |  |  |\\n| --- | --- | --- |\\n| 2023: | 47,322.66822 |  |\\n| 2022: | 47,551.22966 |  |\\n| 2021: | 45,873.86960 |  |\\n| 2020: | 42,215.88375 |  |\\n| 2019: | 47,234.24661 |  |\\n| [View All](/data/NYGDPPCAPKDGBR.txt) | |\\n\\nUnits:\\n\\nFrequency:", "score": 0.7803451}, {"title": "UK GDP 2024 - Statista", "url": "https://www.statista.com/statistics/281744/gdp-of-the-united-kingdom/", "content": "| Characteristic | GDP in million GDP (CVM 2022)\\\\* |\\n| --- | --- |\\n| 2024 | 2,564,378 |\\n| 2023 | 2,536,460 |\\n| 2022 | 2,526,428 |\\n| 2021 | 2,409,815 |\\n| 2020 | 2,219,474 |\\n| 2019 | 2,474,245 |\\n| 2018 | 2,434,694 |\\n| 2017 | 2,400,956 |\\n| 2016 | 2,338,825 |\\n| 2015 | 2,294,727 |\\n| 2014 | 2,244,827 |\\n| 2013 | 2,175,333 |\\n| 2012 | 2,136,871 |\\n| 2011 | 2,105,105 |\\n| 2010 | 2,081,411 |\\n| 2009 | 2,035,942 |\\n| 2008 | 2,134,571 |\\n| 2007 | 2,139,895 |\\n| 2006 | 2,085,162 |\\n| 2005 | 2,036,675 |", "score": 0.7591723}, {"title": "Real GDP - United Kingdom | IBISWorld", "url": "https://www.ibisworld.com/uk/bed/real-gdp/362/", "content": "During 2022-23, real UK GDP is expected to surpass its pre-pandemic level and is forecast to expand by 2.1% year-on-year to reach £2,287.9 billion. On 21 February 2022, the UK government announced its \'living with COVID\' plan, which effectively removed all remaining domestic restrictions, the hope being that market output will remain on an upwards trajectory post-pandemic. However, two years since the onset of the pandemic and in the midst of another unfolding global shock, the domestic economy [...] During 2022-23, real UK GDP is expected to surpass its pre-pandemic level and is forecast to expand by 2.1% year-on-year to reach £2,287.9 billion. On 21 February 2022, the UK government announced its \'living with COVID\' plan, which effectively removed all remaining do ...
#   HumanMessage(content="Let's create a line chart to visualize the UK GDP data from 2020 to 2022 using the following GDP values:\n\n- 2020: $2,696.78 billion\n- 2021: $3,143.32 billion\n- 2022: $3,114.04 billion\n\nPlease create a line chart with this data.", additional_kwargs={}, response_metadata={}, name='researcher', id='a0eca5d7-b59d-4972-9c29-dd5ebbc3b7b2'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_kqetIO1lIfknfmi86mFQOCAZ', 'function': {'arguments': '{"code":"import matplotlib.pyplot as plt\\n\\n# Data for UK GDP\\nyears = [2020, 2021, 2022]\\ngdp_values = [2696.78, 3143.32, 3114.04]  # Values in billion USD\\n\\n# Create a line chart\\nplt.figure(figsize=(10, 6))\\nplt.plot(years, gdp_values, marker=\'o\')\\nplt.title(\'UK GDP from 2020 to 2022\')\\nplt.xlabel(\'Year\')\\nplt.ylabel(\'GDP (Billion USD)\')\\nplt.xticks(years)\\nplt.grid(True)\\nplt.tight_layout()\\n\\n# Display the chart\\nplt.show()"}', 'name': 'python_repl_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 165, 'prompt_tokens': 18039, 'total_tokens': 18204, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BlGsoTOusvrtZn5mFQWqehhjzPwC5', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--fb67383d-660b-4f94-8fd0-654d5b76d030-0', tool_calls=[{'name': 'python_repl_tool', 'args': {'code': "import matplotlib.pyplot as plt\n\n# Data for UK GDP\nyears = [2020, 2021, 2022]\ngdp_values = [2696.78, 3143.32, 3114.04]  # Values in billion USD\n\n# Create a line chart\nplt.figure(figsize=(10, 6))\nplt.plot(years, gdp_values, marker='o')\nplt.title('UK GDP from 2020 to 2022')\nplt.xlabel('Year')\nplt.ylabel('GDP (Billion USD)')\nplt.xticks(years)\nplt.grid(True)\nplt.tight_layout()\n\n# Display the chart\nplt.show()"}, 'id': 'call_kqetIO1lIfknfmi86mFQOCAZ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 18039, 'output_tokens': 165, 'total_tokens': 18204, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Successfully executed:\n\\`\\`\\`python\nimport matplotlib.pyplot as plt\n\n# Data for UK GDP\nyears = [2020, 2021, 2022]\ngdp_values = [2696.78, 3143.32, 3114.04]  # Values in billion USD\n\n# Create a line chart\nplt.figure(figsize=(10, 6))\nplt.plot(years, gdp_values, marker='o')\nplt.title('UK GDP from 2020 to 2022')\nplt.xlabel('Year')\nplt.ylabel('GDP (Billion USD)')\nplt.xticks(years)\nplt.grid(True)\nplt.tight_layout()\n\n# Display the chart\nplt.show()\n\\`\\`\\`\nStdout: \n\nIf you have completed all tasks, respond with FINAL ANSWER.", name='python_repl_tool', id='a99799a6-83e2-4b44-8b94-019d6d716a97', tool_call_id='call_kqetIO1lIfknfmi86mFQOCAZ'),
#   HumanMessage(content="The line chart visualizing the UK's GDP from 2020 to 2022 has been successfully created. \n\nFINAL ANSWER: The line chart has been generated and displayed, showing the UK's GDP values for 2020, 2021, and 2022 in billion USD.", additional_kwargs={}, response_metadata={}, name='chart_generator', id='4414304e-c0c5-4bd4-a76d-0fbc163590d2')]}

# %% [markdown]
# code="""import matplotlib.pyplot as plt\\n\\n# Data for the UK GDP over the past 3 years\\nyears = [2019, 2020, 2021]\\ngdp_values = [2851.41, 2697.81, 3141.51]  # in billion $ \\n\\ndef create_line_chart(years, gdp_values):\\n    plt.figure(figsize=(10, 6))\\n    plt.plot(years, gdp_values, marker=\'o\', color=\'b\', linestyle=\'-\', linewidth=2)\\n    plt.title(\'UK GDP Over the Past 3 Years\')\\n    plt.xlabel(\'Year\')\\n    plt.ylabel(\'GDP (in billion $)\')\\n    plt.grid(True)\\n    plt.tight_layout()\\n    plt.show()"""

# %%
code="""import matplotlib.pyplot as plt\\n\\n# Data for the UK GDP over the past 3 years\\nyears = [2019, 2020, 2021]\\ngdp_values = [2851.41, 2697.81, 3141.51]  # in billion $ \\n\\ndef create_line_chart(years, gdp_values):\\n    plt.figure(figsize=(10, 6))\\n    plt.plot(years, gdp_values, marker=\'o\', color=\'b\', linestyle=\'-\', linewidth=2)\\n    plt.title(\'UK GDP Over the Past 3 Years\')\\n    plt.xlabel(\'Year\')\\n    plt.ylabel(\'GDP (in billion $)\')\\n    plt.grid(True)\\n    plt.tight_layout()\\n    plt.show()"""

# %%
print("""import matplotlib.pyplot as plt\\n\\n# Data for the UK GDP over the past 3 years\\nyears = [2019, 2020, 2021]\\ngdp_values = [2851.41, 2697.81, 3141.51]  # in billion $ \\n\\ndef create_line_chart(years, gdp_values):\\n    plt.figure(figsize=(10, 6))\\n    plt.plot(years, gdp_values, marker=\'o\', color=\'b\', linestyle=\'-\', linewidth=2)\\n    plt.title(\'UK GDP Over the Past 3 Years\')\\n    plt.xlabel(\'Year\')\\n    plt.ylabel(\'GDP (in billion $)\')\\n    plt.grid(True)\\n    plt.tight_layout()\\n    plt.show()""")
# Out:
# import matplotlib.pyplot as plt\n\n# Data for the UK GDP over the past 3 years\nyears = [2019, 2020, 2021]\ngdp_values = [2851.41, 2697.81, 3141.51]  # in billion $ \n\ndef create_line_chart(years, gdp_values):\n    plt.figure(figsize=(10, 6))\n    plt.plot(years, gdp_values, marker='o', color='b', linestyle='-', linewidth=2)\n    plt.title('UK GDP Over the Past 3 Years')\n    plt.xlabel('Year')\n    plt.ylabel('GDP (in billion $)')\n    plt.grid(True)\n    plt.tight_layout()\n    plt.show()
